# %%
import pandas as pd
import datetime as dt
import seaborn as sb
import matplotlib.pyplot as plt

# %%
Sales_data=pd.read_csv('Sales Data.csv')
Sales_data
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0                0    295665      Macbook Pro Laptop                 1
# 1                1    295666      LG Washing Machine                 1
# 2                2    295667    USB-C Charging Cable                 1
# 3                3    295668        27in FHD Monitor                 1
# 4                4    295669    USB-C Charging Cable                 1
# ...            ...       ...                     ...               ...
# 185945       13617    222905  AAA Batteries (4-pack)                 1
# 185946       13618    222906        27in FHD Monitor                 1
# 185947       13619    222907    USB-C Charging Cable                 1
# 185948       13620    222908    USB-C Charging Cable                 1
# 185949       13621    222909  AAA Batteries (4-pack)                 1
#
#         Price Each           Order Date  \
# 0          1700.00  2019-12-30 00:01:00
# ...

# %%
Sales_data['Order Date']

# %%
Order_date=[]
Sales_data['Order Date']
for date_ in Sales_data['Order Date']:
    date_=str(date_)
    Order_date.append(int(date_[5:7]))
Sales_data['Order Date']=Order_date

# %%
No_of_products=[]
products=Sales_data['Product'].unique()
products=list(products)
length=len(Sales_data)
for product_ in products:
    count=0;
    product_count=0
    while(count<length):
        if(Sales_data.loc[count,'Product']==product_):
            product_count=product_count+Sales_data.loc[count,'Quantity Ordered']
        count+=1
    No_of_products.append(product_count)

# %%
df= df.sort_values(by='No_of_products_Sale', ascending=False)
df
# Out:
#                       products  No_of_products_Sale
# 6       AAA Batteries (4-pack)                31017
# 4        AA Batteries (4-pack)                27635
# 2         USB-C Charging Cable                23975
# 8     Lightning Charging Cable                23217
# 10            Wired Headphones                20557
# 11    Apple Airpods Headphones                15661
# 5   Bose SoundSport Headphones                13457
# 3             27in FHD Monitor                 7550
# 13                      iPhone                 6849
# 17      27in 4K Gaming Monitor                 6244
# 15      34in Ultrawide Monitor                 6199
# 9                 Google Phone                 5532
# 16               Flatscreen TV                 4819
# 0           Macbook Pro Laptop                 4728
# 7              ThinkPad Laptop                 4130
# 14                20in Monitor                 4129
# 12             Vareebadd Phone                 2068
# ...

# %%
data = {
    'products': products,
    'No_of_products_Sale': No_of_products,
}
df = pd.DataFrame(data)
sb.barplot(x='products',y='No_of_products_Sale',data=df)
plt.xticks(rotation=90)
plt.tight_layout()

# %%
sb.boxplot(x='Product',y='Order Date',data=Sales_data)
plt.xticks(rotation=90)
plt.tight_layout()
